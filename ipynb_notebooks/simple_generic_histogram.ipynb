# %%
import numpy as np
import polars as pl

import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from src.file_locations import intermediate_files_location
from src.plot_helpers import make_histogram_plot
from src.df_helpers import lazy_height

# Independent systematics toggles: each adds its uncertainty band to every plot below
# when True.  With both False the notebook behaves exactly as before (statistical
# uncertainties only), and the corresponding dataframe is not even loaded.
use_rw_systematics = True       # reweighting (GENIE/flux/reint) multisim systematics
use_detvar_systematics = True   # detector-variation systematics

# When True, the systematic covariance matrices are recomputed from scratch instead of
# being read from the on-disk systematic cache (use after the inputs change, or to
# refresh a stale cache).  Applies to both rw and detvar systematics.
dont_load_systematics_from_cache = False

# %% [markdown]
# # File Loading

# %%
print("loading all_df.parquet...")
all_df = pl.scan_parquet(f"{intermediate_files_location}/all_df.parquet")
print(f"num events in all_df: {lazy_height(all_df)}")

# Systematics inputs: each is loaded only when its toggle is on (so plain plots don't pay
# for reading the large weights dataframe).
weights_df = None
detvar_df = None
if use_rw_systematics:
    print("loading presel_weights_df.parquet (reweighting systematics)...")
    weights_df = pl.read_parquet(f"{intermediate_files_location}/presel_weights_df.parquet")
if use_detvar_systematics:
    print("loading detvar_presel_df_train_vars.parquet (detector-variation systematics)...")
    detvar_df = pl.read_parquet(f"{intermediate_files_location}/detvar_presel_df_train_vars.parquet")

# %% [markdown]
# # Configuration
#
# `base_presel` is the generic preselection shared by every section: it drops the
# raw `isotropic_one_gamma_overlay` / `delete_one_gamma_overlay` events (their
# reweighted versions are kept as the `NC_coherent_1g_reweighted` /
# `numuCC_rad_corrected` filetypes) and requires a reconstructed neutrino energy.
#
# `plot_one` makes a single stacked prediction histogram for one weighting config:
#
# - the per-config net weight (`net_weight_var`) selects which prediction we draw,
#   and rows with a null weight in that config are dropped automatically;
# - the POT shown on the axis/labels is read from the dataframe's
#   `norm_goal_pot_<config>` column (per run period when filtered to one, or the
#   total when combined) -- nothing is hardcoded;
# - `data_filetype` is `"data"` for real open data, `"nuwro_fake_data"` for the
#   NuWro fake-data study, or `None` for the full prediction (no data).

# %%
VAR = "wc_kine_reco_Enu"
DISPLAY_VAR = r"WC Reconstructed $E_\nu$ (MeV)"
BINS = np.linspace(0, 2000, 21)
SEL_TITLE = "WC Generic Selection"

base_presel = all_df.filter(
    ~pl.col("filetype").is_in(["isotropic_one_gamma_overlay", "delete_one_gamma_overlay", "fullosc_overlay"])
    & (pl.col("wc_kine_reco_Enu") > 0)
)


def plot_one(sub, weight_var, data_filetype, data_label, title, selname):
    """One stacked prediction histogram for a weighting config (POT read from the df).

    Reweighting and/or detector-variation systematic bands are drawn according to the
    independent top-level ``use_rw_systematics`` / ``use_detvar_systematics`` toggles
    (using ``weights_df`` / ``detvar_df``); with both off this is statistical-only,
    exactly as before.  ``dont_load_systematics_from_cache`` forces a recompute of both
    covariance matrices instead of reading the on-disk cache."""
    if data_filetype is not None:
        pred = sub.filter(pl.col(weight_var).is_not_null() & (pl.col("filetype") != data_filetype))
        data = sub.filter(pl.col("filetype") == data_filetype)
        make_histogram_plot(
            pred_sel_df=pred, data_sel_df=data,
            bins=BINS, var=VAR, display_var=DISPLAY_VAR,
            net_weight_var=weight_var, data_type=data_label,
            title=title, selname=selname,
            use_rw_systematics=use_rw_systematics, weights_df=weights_df,
            use_detvar_systematics=use_detvar_systematics, detvar_df=detvar_df,
            dont_load_rw_from_systematic_cache=dont_load_systematics_from_cache,
            dont_load_detvar_from_systematic_cache=dont_load_systematics_from_cache,
            num_bootstrap_rounds_detvar=500, num_bootstrap_samples_detvar=500,
        )
    else:
        pred = sub.filter(pl.col(weight_var).is_not_null())
        make_histogram_plot(
            pred_sel_df=pred, include_data=False, include_ratio=False,
            bins=BINS, var=VAR, display_var=DISPLAY_VAR,
            net_weight_var=weight_var,
            title=title, selname=selname,
            use_rw_systematics=use_rw_systematics, weights_df=weights_df,
            use_detvar_systematics=use_detvar_systematics, detvar_df=detvar_df,
            dont_load_rw_from_systematic_cache=dont_load_systematics_from_cache,
            dont_load_detvar_from_systematic_cache=dont_load_systematics_from_cache,
            num_bootstrap_rounds_detvar=500, num_bootstrap_samples_detvar=500,
        )

# %% [markdown]
# # Open Data (runs 1-5)
#
# Overlays normalized per group to the open-data POT (`wc_net_weight_open_data`):
# run 1 -> run 1 data, runs 2-3 -> run 3 data, run 4a -> run 4a data,
# runs 4b-5 -> run 4b data.

# %%
# separate data run periods
weight_var = "wc_net_weight_open_data"
nrp_col = "normalizing_run_period_open_data"
open_data_groups = {"1": "Run 1", "23": "Run 3", "4a": "Run 4a", "4nota5": "Run 4b"}

for group, label in open_data_groups.items():
    sub = base_presel.filter(pl.col(nrp_col) == group)
    plot_one(sub, weight_var, "data", f"{label} Open Data",
             f"{SEL_TITLE} \u2014 {label} Open Data", f"generic_opendata_{group}")

# %%
# all run periods combined
plot_one(base_presel, "wc_net_weight_open_data", "data", "Runs 1-5 Open Data",
         f"{SEL_TITLE} \u2014 Runs 1-5 Open Data (combined)", "generic_opendata_combined")

# %%
# all run periods combined
plot_one(base_presel, "wc_net_weight_open_data", "data", "Runs 1-5 Open Data",
         f"{SEL_TITLE} \u2014 Runs 1-5 Open Data (combined)", "generic_opendata_combined")

# %% [markdown]
# # NuWro Fake Data
#
# NuWro fake data plays the data role (`wc_net_weight_nuwro`); the GENIE overlays
# are normalized per group to the NuWro POT.  EXT, dirt, and real data are excluded
# (they were not part of the fake-data study).  NuWro exists for periods
# 1, 2, 3, 4a, 4c, 5; runs 4b/4d/4bcd overlays are folded into the run 4c group.

# %%
# separate run periods
weight_var = "wc_net_weight_nuwro"
nrp_col = "normalizing_run_period_nuwro"
nuwro_groups = {"1": "Run 1", "2": "Run 2", "3": "Run 3", "4a": "Run 4a", "4c": "Run 4c", "5": "Run 5"}

for group, label in nuwro_groups.items():
    sub = base_presel.filter(pl.col(nrp_col) == group)
    plot_one(sub, weight_var, "nuwro_fake_data", f"{label} NuWro Fake Data",
             f"{SEL_TITLE} \u2014 {label} NuWro Fake Data", f"generic_nuwro_{group}")

# %%
# all run periods combined
plot_one(base_presel, "wc_net_weight_nuwro", "nuwro_fake_data", "Runs 1-5 NuWro Fake Data",
         f"{SEL_TITLE} \u2014 NuWro Fake Data (combined)", "generic_nuwro_combined")

# %% [markdown]
# # Full Runs 1-5 Prediction
#
# Overlays (plus EXT and dirt) normalized to the expected full-dataset POT per run
# period (`wc_net_weight_full_pred`).  There is no data to compare against here, so
# only the stacked prediction is drawn (run 4a is kept separate; runs 4b/4c/4d/4bcd
# are combined as "4nota").

# %%
# separate run periods
weight_var = "wc_net_weight_full_pred"
nrp_col = "normalizing_run_period_full_pred"
full_pred_groups = {"1": "Run 1", "2": "Run 2", "3": "Run 3", "4a": "Run 4a", "4nota": "Runs 4b-4d", "5": "Run 5"}

for group, label in full_pred_groups.items():
    sub = base_presel.filter(pl.col(nrp_col) == group)
    plot_one(sub, weight_var, None, None,
             f"{SEL_TITLE} \u2014 {label} Full Prediction", f"generic_fullpred_{group}")

# %%
# all run periods combined
plot_one(base_presel, "wc_net_weight_full_pred", None, None,
         f"{SEL_TITLE} \u2014 Runs 1-5 Full Prediction (combined)", "generic_fullpred_combined")
