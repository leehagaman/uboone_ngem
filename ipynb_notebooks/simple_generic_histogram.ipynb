# %%
import numpy as np
import polars as pl

import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from src.file_locations import intermediate_files_location

from src.plot_helpers import make_histogram_plot

from src.df_helpers import lazy_height

# %% [markdown]
# # File Loading

# %%
print("loading all_df.parquet...")
all_df = pl.scan_parquet(f"{intermediate_files_location}/all_df.parquet")
print(f"num events in all_df: {lazy_height(all_df)}")

print("loading presel_detvar_df.parquet...")
detvar_df = pl.scan_parquet(f"{intermediate_files_location}/detvar_presel_df_train_vars.parquet")
print(f"num events in detvar_df: {lazy_height(detvar_df)}")

print("loading weights_df.parquet...")
weights_df = pl.scan_parquet(f"{intermediate_files_location}/presel_weights_df.parquet")
print(f"num events in weights_df: {lazy_height(weights_df)}")

# %%
full_pred_data = all_df.filter(
    ~pl.col("filetype").is_in(["isotropic_one_gamma_overlay", "delete_one_gamma_overlay"])
)
presel_merged_df = full_pred_data.filter(pl.col("wc_kine_reco_Enu") > 0)

# don't need to apply any cuts to weights_df (gets event-by-event matched to presel_merged_df)
# don't need to apply any cuts to detvar_df (already generic neutrino selection in this case)

# %% [markdown]
# # Preselection Histogram

# %%
make_histogram_plot(
    pred_and_data_sel_df=presel_merged_df,
    bins=np.linspace(0, 2000, 21),
    var="wc_kine_reco_Enu",
    display_var=r"WC Reconstructed $E_\nu$ (GeV)",
    title="Run 4a+4b WC Inclusive 1g Selection",
    selname="generic_presel_4a4b",
    data_type="4a+4b open data",
    net_weight_var="wc_net_weight",
    use_rw_systematics=True, weights_df=weights_df,
    use_detvar_systematics=True, detvar_df=detvar_df, num_bootstrap_rounds_detvar=500, num_bootstrap_samples_detvar=500
)

# %%
make_histogram_plot(
    pred_and_data_sel_df=presel_merged_df.filter(pl.col("detailed_run_period") != "4a"),
    bins=np.linspace(0, 2000, 21),
    var="wc_kine_reco_Enu",
    display_var=r"WC Reconstructed $E_\nu$ (GeV)",
    title="Run 4b WC Inclusive 1g Selection",
    selname="generic_presel_4b",
    data_type="4b open data",
    net_weight_var="wc_net_weight",
    use_rw_systematics=True, weights_df=weights_df,
    use_detvar_systematics=True, detvar_df=detvar_df, num_bootstrap_rounds_detvar=500, num_bootstrap_samples_detvar=500
)

# %%
make_histogram_plot(
    pred_and_data_sel_df=presel_merged_df.filter(pl.col("detailed_run_period") == "4b"),
    bins=np.linspace(0, 2000, 21),
    var="wc_kine_reco_Enu",
    display_var=r"WC Reconstructed $E_\nu$ (GeV)",
    title="Run 4b WC Inclusive 1g Selection (4b pred only)",
    selname="generic_presel_4b_4bonlypred",
    data_type="4b open data",
    net_weight_var="run4b_only_wc_net_weight",
    use_rw_systematics=True, weights_df=weights_df,
    use_detvar_systematics=True, detvar_df=detvar_df, num_bootstrap_rounds_detvar=500, num_bootstrap_samples_detvar=500
)
